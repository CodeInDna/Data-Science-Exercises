# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0                          ['oh', 'send', 'address']
# 1                     ['take', 'exam', 'march', '3']
# 2  ['xmas', 'story', 'peace', 'xmas', 'msg', 'lov...
# 3             ['dont', 'talk', 'ever', 'ok', 'word']
# 4                          ['send', 'new', 'number']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])

X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'oh': 5162,
#  'send': 6303,
#  'address': 875,
#  'take': 7016,
#  'exam': 2794,
#  'march': 4540,
#  'xmas': 8051,
#  'story': 6831,
#  'peace': 5397,
#  'msg': 4825,
#  'love': 4407,
#  'miracle': 4703,
#  'jesus': 3973,
#  'hav': 3460,
#  'blessed': 1455,
#  'month': 4783,
#  'ahead': 934,
#  'amp': 1017,
#  'wish': 7890,
#  'merry': 4644,
#  'dont': 2516,
#  'talk': 7024,
#  'ever': 2770,
#  'ok': 5169,
#  'word': 7940,
#  'new': 4969,
#  'number': 5099,
#  'special': 6674,
#  'called': 1685,
#  'mom': 4766,
#  'instead': 3850,
#  'fun': 3139,
#  'cant': 1718,
#  'pick': 5462,
#  'phone': 5451,
#  'right': 6067,
#  'pls': 5519,
#  'message': 4649,
#  'lol': 4366,
#  'yeah': 8081,
#  'point': 5549,
#  'guess': 3376,
#  'fyi': 3151,
#  'im': 3763,
#  'usf': 7570,
#  'swing': 6985,
#  'room': 6107,
#  'whenever': 7833,
#  'haf': 3403,
#  'found': 3065,
#  'feel': 2907,
#  'stupid': 6875,
#  'da': 2230,
#  'cam': 1699,
#  'working': 7950,
#  'santa': 6192,
#  'calling': 1691,
#  'would': 7970,
#  'little': 4330,
#  'ones': 5197,
#  'like': 4291,
#  'call': 1671,
#  'eve': 2762,
#  '09077818151': 239,
#  'book': 1498,
#  'time': 7233,
#  'calls150ppm': 1694,
#  'last': 4201,
#  '3mins': 512,
#  '30s': 476,
#  'tc': 7054,
#  'wwwsantacallingcom': 8026,
#  'urgent': 7551,
#  'please': 5512,
#  '09061743811': 198,
#  'landline': 4183,
#  'abta': 828,
#  'complimentary': 2014,
#  'tenerife': 7100,
#  'holiday': 3598,
#  '5000': 589,
#  'cash': 1756,
#  'await': 1234,
#  'collection': 1969,
#  'sae': 6164,
#  'tcs': 7057,
#  'box': 1524,
#  '326': 484,
#  'cw25wx': 2228,
#  '150ppm': 329,
#  'freemsg': 3089,
#  'hey': 3537,
#  'got': 3306,
#  'videopic': 7631,
#  'fones': 3032,
#  'reply': 5993,
#  'wild': 7867,
#  'txt': 7435,
#  'ill': 3760,
#  'pics': 5466,
#  'hurry': 3709,
#  'bored': 1508,
#  'work': 7946,
#  'xxx': 8057,
#  '18': 347,
#  '150prcvd': 331,
#  'stop2stop': 6818,
#  'congrats': 2045,
#  'nokia': 5035,
#  '3650': 491,
#  'video': 7628,
#  'camera': 1702,
#  '09066382422': 233,
#  'calls': 1693,
#  'cost': 2105,
#  'ave': 1225,
#  'vary': 7605,
#  'mobiles': 4747,
#  '16': 342,
#  'close': 1930,
#  '300603': 470,
#  'post': 5594,
#  'bcm4284': 1334,
#  'ldn': 4226,
#  'wc1n3xx': 7761,
#  'yo': 8112,
#  'howz': 3663,
#  'girls': 3236,
#  'never': 4965,
#  'rang': 5845,
#  'india': 3809,
#  'wow': 7973,
#  'realized': 5882,
#  'embarassed': 2683,
#  'accomodations': 840,
#  'thought': 7197,
#  'liked': 4292,
#  'since': 6473,
#  'best': 1394,
#  'could': 2115,
#  'always': 1005,
#  'seemed': 6284,
#  'happy': 3443,
#  'cave': 1772,
#  'sorry': 6639,
#  'didnt': 2406,
#  'give': 3238,
#  'offered': 5144,
#  'embarassing': 2684,
#  'customer': 2217,
#  'service': 6327,
#  'announcement': 1042,
#  'recently': 5905,
#  'tried': 7379,
#  'make': 4510,
#  'delivery': 2342,
#  'unable': 7476,
#  '07099833605': 23,
#  'reschedule': 6007,
#  'ref9280114': 5928,
#  'current': 2209,
#  'leading': 4231,
#  'bid': 1413,
#  '151': 338,
#  'pause': 5386,
#  'auction': 1203,
#  'care': 1731,
#  '08718726270': 140,
#  'cheers': 1838,
#  'card': 1727,
#  'year': 8082,
#  'already': 994,
#  'thk': 7188,
#  'juz': 4033,
#  'go': 3255,
#  'accordin': 841,
#  'wat': 7742,
#  'discussed': 2458,
#  'yest': 8103,
#  'lor': 4385,
#  'except': 2797,
#  'kb': 4064,
#  'sun': 6925,
#  'cos': 2103,
#  'theres': 7169,
#  'nt': 5091,
#  'much': 4844,
#  'lesson': 4257,
#  'attend': 1196,
#  'sat': 6203,
#  'idc': 3737,
#  'get': 3211,
#  'weaseling': 7768,
#  'way': 7757,
#  'shit': 6394,
#  'twice': 7430,
#  'row': 6117,
#  'hot': 3643,
#  'live': 4331,
#  'fantasies': 2878,
#  '08707509020': 85,
#  '20p': 392,
#  'per': 5412,
#  'min': 4684,
#  'ntt': 5094,
#  'ltd': 4431,
#  'po': 5527,
#  '1327': 301,
#  'croydon': 2176,
#  'cr9': 2140,
#  '5wb': 619,
#  '0870': 66,
#  'national': 4918,
#  'rate': 5850,
#  'prob': 5699,
#  'jus': 4029,
#  'came': 1701,
#  'back': 1263,
#  'fr': 3071,
#  'lunch': 4448,
#  'wif': 7858,
#  'sis': 6487,
#  'leh': 4246,
#  'switch': 6987,
#  'fone': 3030,
#  'dammit': 2245,
#  'even': 2765,
#  'spirit': 6696,
#  'bb': 1325,
#  'soon': 6630,
#  'trying': 7398,
#  'sure': 6953,
#  'need': 4939,
#  'wan': 7719,
#  'meet': 4607,
#  'later': 4209,
#  'cool': 2087,
#  'text': 7117,
#  'youre': 8128,
#  'ready': 5874,
#  'guaranteed': 3369,
#  '1000': 256,
#  '2000': 383,
#  'prize': 5693,
#  'claim': 1904,
#  'yr': 8139,
#  'representative': 5999,
#  '08714712379': 116,
#  '10am7pm': 269,
#  '10p': 272,
#  'oktake': 5178,
#  'careumma': 1740,
#  'apps': 1105,
#  'class': 1910,
#  'varaya': 7601,
#  'elaya': 2668,
#  'hello': 3501,
#  'peach': 5399,
#  'cake': 1662,
#  'tasts': 7040,
#  'lush': 4451,
#  'long': 4372,
#  'applebees': 1089,
#  'fucking': 3128,
#  'hopeing': 3628,
#  'pissed': 5485,
#  'remember': 5966,
#  'gone': 3280,
#  'sisters': 6489,
#  'something': 6612,
#  'todaysundaysunday': 7275,
#  'holidayso': 3599,
#  'ned': 4938,
#  'toa': 7265,
#  'payoh': 5394,
#  'return': 6046,
#  'smth': 6575,
#  'ssindia': 6740,
#  'going': 3274,
#  'draw': 2546,
#  'series': 6322,
#  'many': 4536,
#  'years': 8083,
#  'south': 6657,
#  'african': 909,
#  'soil': 6597,
#  'surely': 6954,
#  'result': 6039,
#  'offer': 5143,
#  'think': 7180,
#  'away': 1239,
#  'trek': 7376,
#  'family': 2871,
#  'town': 7340,
#  'enufcredeit': 2727,
#  'tocallshall': 7268,
#  'ileave': 3759,
#  'uni': 7499,
#  'bus': 1633,
#  'yor': 8116,
#  'house': 3651,
#  'itll': 3915,
#  'tough': 7336,
#  'gas': 3173,
#  'station': 6776,
#  'block': 1461,
#  'youll': 8125,
#  'drive': 2564,
#  'armenia': 1134,
#  'ends': 2701,
#  'swann': 6969,
#  'howard': 3656,
#  'brand': 1547,
#  'mobile': 4746,
#  'agent': 924,
#  'mob': 4745,
#  'plus': 5523,
#  'loads': 4343,
#  'goodies': 3290,
#  'info': 3822,
#  'mat': 4559,
#  '87021': 747,
#  'despite': 2375,
#  'cramps': 2145,
#  'girl': 3232,
#  'friend': 3104,
#  'says': 6223,
#  'hes': 3532,
#  'upping': 7541,
#  'order': 5241,
#  'grams': 3323,
#  'ltgt': 4436,
#  'bought': 1519,
#  'test': 7112,
#  'yesterday': 8104,
#  'lets': 4260,
#  'know': 4131,
#  'exact': 2792,
#  'day': 2276,
#  'ovulatewhen': 5289,
#  '2u': 459,
#  '3wks': 524,
#  'fret': 3099,
#  'worried': 7959,
#  'relax': 5955,
#  'also': 1000,
#  'anything': 1067,
#  'ur': 7549,
#  'past': 5375,
#  'history': 3562,
#  'tell': 7086,
#  'good': 3284,
#  'evening': 2766,
#  'sir': 6483,
#  'al': 959,
#  'salam': 6175,
#  'wahleykkumsharing': 7695,
#  'newsby': 4974,
#  'grace': 3320,
#  'god': 3263,
#  'tayseertissco': 7051,
#  'joinedhope': 3993,
#  'fineinshah': 2955,
#  'allahmeet': 980,
#  'sometimerakheshvisitor': 6614,
#  'bishan': 1435,
#  'lei': 4247,
#  'tot': 7330,
#  'say': 6219,
#  'lavender': 4220,
#  'darlin': 2257,
#  'ive': 3928,
#  'finished': 2961,
#  'college': 1970,
#  'finish': 2959,
#  'kate': 4058,
#  '22': 399,
#  '146tf150p': 307,
#  'game': 3161,
#  'almost': 990,
#  'want': 7723,
#  'walmart': 7717,
#  'thank': 7134,
#  'shock': 6402,
#  'telling': 7087,
#  'shuhui': 6438,
#  'leona': 4251,
#  'dat': 2265,
#  'liao': 4265,
#  'ask': 1162,
#  'abt': 827,
#  'reaction': 5870,
#  'woke': 7922,
#  'yeesh': 8084,
#  'late': 4204,
#  'fall': 2865,
#  'asleep': 1169,
#  'til': 7230,
#  'ure': 7550,
#  'done': 2513,
#  'ìï': 8166,
#  'still': 6803,
#  'lessons': 4258,
#  'sch': 6233,
#  'seems': 6285,
#  'unnecessarily': 7514,
#  'hostile': 3642,
#  'mins': 4695,
#  'pay': 5387,
#  'ltdecimalgt': 4432,
#  'lakhs': 4176,
#  'reached': 5867,
#  'important': 3778,
#  'hrishi': 3667,
#  'credits': 2160,
#  'topped': 7323,
#  'httpwwwbubbletextcom': 3677,
#  'renewal': 5978,
#  'pin': 5480,
#  'tgxxrz': 7129,
#  'contact': 2060,
#  '750': 673,
#  '150': 309,
#  'textand': 7119,
#  '08002988890': 53,
#  'free': 3083,
#  'tomorrow': 7295,
#  'yep': 8090,
#  'dereks': 2364,
#  'see': 6278,
#  'sunday': 6927,
#  'lt3': 4430,
#  'kappa': 4054,
#  'outside': 5278,
#  'mu': 4843,
#  'wewa': 7826,
#  '130': 300,
#  'iriver': 3890,
#  '255': 413,
#  '128': 294,
#  'mb': 4585,
#  'kanowhr': 4053,
#  'treat': 7370,
#  'maga': 4492,
#  'gibbs': 3223,
#  'unsoldmike': 7520,
#  'hussey': 3714,
#  'yar': 8075,
#  'knew': 4128,
#  'dis': 2446,
#  'happen': 3433,
#  'ago': 929,
#  'today': 7270,
#  'iz': 3929,
#  'yellow': 8087,
#  'rose': 6112,
#  'frndship': 3114,
#  'misscall': 4712,
#  'frndz': 3116,
#  'miss': 4711,
#  '6missed': 654,
#  'marry': 4551,
#  'lover': 4412,
#  'dear': 2294,
#  'sleeping': 6521,
#  'jos': 4007,
#  'wana': 7721,
#  'nothing': 5067,
#  'ba': 1251,
#  'gua': 3367,
#  'went': 7812,
#  'mt': 4838,
#  'faber': 2845,
#  'mah': 4498,
#  'said': 6171,
#  'wisdom': 7888,
#  'teeth': 7079,
#  'hidden': 3544,
#  'inside': 3844,
#  'mayb': 4583,
#  'remove': 5975,
#  'cal': 1665,
#  'bhaskar': 1410,
#  'deep': 2320,
#  'tone': 7299,
#  'club': 1940,
#  'subs': 6887,
#  'expired': 2823,
#  'resub': 6036,
#  'monoc': 4780,
#  'monos': 4781,
#  'polyc': 5560,
#  'polys': 5564,
#  'weekly': 7789,
#  '150p': 314,
#  'week': 7786,
#  'stop': 6816,
#  'stream': 6838,
#  '0871212025016': 95,
#  'well': 7804,
#  'blimey': 1459,
#  'exercise': 2806,
#  'kinda': 4101,
#  'wot': 7968,
#  'hmm': 3576,
#  'yup': 8146,
#  'thanx': 7140,
#  'printing': 5685,
#  'handing': 3424,
#  'aft': 910,
#  'str': 6832,
#  'orchard': 5240,
#  'wan2': 7720,
#  'win': 7872,
#  'meetgreet': 4608,
#  'westlife': 7820,
#  'm8': 4469,
#  'currently': 2210,
#  'tour': 7338,
#  '1unbreakable': 376,
#  '2untamed': 460,
#  '3unkempt': 520,
#  '12': 285,
#  '83049': 719,
#  '50p': 593,
#  'std': 6784,
#  'vl': 7658,
#  'bcum': 1337,
#  'difficult': 2421,
#  'sth': 6800,
#  'specs': 6680,
#  'membership': 4624,
#  'px3748': 5785,
#  'chief': 1855,
#  'bell': 1379,
#  'royal': 6121,
#  'visit': 7651,
#  '1st': 371,
#  'june': 4026,
#  'haha': 3404,
#  'awesome': 1240,
#  'might': 4674,
#  'doin': 2502,
#  'tonight': 7306,
#  'everything': 2779,
#  'actually': 865,
#  'better': 1402,
#  'ownyouve': 5297,
#  'money': 4773,
#  'man': 4520,
#  'rent': 5981,
#  'fill': 2937,
#  'tank': 7032,
#  'yes': 8092,
#  'stressed': 6842,
#  'depressed': 2359,
#  'home': 3604,
#  'thanksgiving': 7137,
#  'cuz': 2227,
#  'wait': 7697,
#  'thats': 7150,
#  'clear': 1918,
#  'sarcastic': 6198,
#  'doesnt': 2493,
#  'us': 7560,
#  'thanks': 7135,
#  'ringtone': 6074,
#  'reference': 5930,
#  'x29': 8042,
#  'charged': 1811,
#  '450': 549,
#  'arrive': 1146,
#  'services': 6328,
#  '09065989180': 217,
#  'cbe': 1773,
#  'really': 5884,
#  'nowadayslot': 5078,
#  'shop': 6407,
#  'showroomscity': 6433,
#  'shaping': 6365,
#  'ard': 1118,
#  'guy': 3389,
#  'kadeem': 4037,
#  'hasnt': 3453,
#  'selling': 6297,
#  'break': 1555,
#  'one': 5195,
#  'paranoid': 5340,
#  'fuck': 3125,
#  'without': 7901,
#  'read': 5871,
#  'shame': 6361,
#  'takes': 7019,
#  'runs': 6150,
#  'blame': 1448,
#  'honey': 3614,
#  'find': 2950,
#  'sell': 6296,
#  'predicte': 5641,
#  'nigeria': 4989,
#  'times': 7236,
#  'used': 7565,
#  'monday': 4771,
#  'babe': 1255,
#  '4get': 566,
#  'itboth': 3907,
#  'try': 7396,
#  'cheer': 1836,
#  'upnot': 7539,
#  'fit': 2976,
#  'soo': 6629,
#  'muchxxlove': 4848,
#  'locaxx': 4350,
#  'nice': 4982,
#  'bit': 1436,
#  'different': 2420,
#  'weekends': 7788,
#  'change': 1801,
#  'ya': 8067,
#  'opinion': 5223,
#  'jada': 3938,
#  'kusruthi': 4153,
#  'lovable': 4406,
#  'silent': 6462,
#  'spl': 6700,
#  'character': 1808,
#  'matured': 4574,
#  'stylish': 6880,
#  'simple': 6468,
#  'ttyl': 7410,
#  'anytime': 1070,
#  'network': 4961,
#  'five': 2978,
#  'pounds': 5606,
#  '08000776320': 45,
#  'macha': 4476,
#  'upseti': 7544,
#  'assume': 1176,
#  'mindsetbelieve': 4687,
#  'wonderful': 7930,
#  'plans': 5501,
#  'uslet': 7574,
#  'life': 4276,
#  'begin': 1371,
#  'againcall': 917,
#  'keep': 4068,
#  'mind': 4686,
#  'enough': 2717,
#  'round': 6115,
#  'trip': 7380,
#  'barring': 1304,
#  'sudden': 6905,
#  'influx': 3821,
#  'issues': 3905,
#  'california': 1669,
#  'okay': 5170,
#  'snow': 6586,
#  'manageable': 4522,
#  'hack': 3400,
#  'chat': 1821,
#  'backdoor': 1265,
#  'entry': 2726,
#  '121': 289,
#  'rooms': 6110,
#  'fraction': 3072,
#  'neo69': 4954,
#  '09050280520': 169,
#  'subscribe': 6888,
#  '25p': 415,
#  'pm': 5526,
#  'dps': 2539,
#  'bcm': 1332,
#  '8027': 701,
#  'textin': 7123,
#  'bout': 1521,
#  'explicit': 2828,
#  'sex': 6340,
#  '30': 467,
#  'secs': 6272,
#  'ring': 6072,
#  '02073162414': 11,
#  'costs': 2108,
#  '20pmin': 393,
#  'gsex': 3364,
#  'pobox': 5529,
#  '2667': 417,
#  'wc1n': 7760,
#  '3xx': 525,
#  'click': 1924,
#  'delete': 2335,
#  'monthly': 4784,
#  'amount': 1016,
#  'terrible': 7107,
#  'till': 7231,
#  '6months': 655,
#  'finishing': 2963,
#  'school': 6235,
#  'great': 3339,
#  'news': 4973,
#  'freefone': 3086,
#  '08006344447': 54,
#  'gift': 3225,
#  'speak': 6672,
#  'operator': 5222,
#  'lateso': 4210,
#  'morningtake': 4797,
#  'sweet': 6976,
#  'dreamsu': 2554,
#  'meummifyingbye': 4665,
#  'cheap': 1825,
#  'splash': 6701,
#  'wine': 7877,
#  'makes': 4511,
#  'gwr': 3393,
#  'beauty': 1348,
#  'next': 4978,
#  'second': 6265,
#  'hides': 3546,
#  'thousands': 7200,
#  'secrets': 6271,
#  'every': 2771,
#  'gud': 3371,
#  'n8': 4889,
#  'eek': 2644,
#  'lot': 4394,
#  'especially': 2747,
#  'american': 1010,
#  'pie': 5470,
#  'minutes': 4701,
#  'singing': 6476,
#  'place': 5489,
#  'walk': 7707,
#  'meh': 4614,
#  'smokes': 6567,
#  'spend': 6686,
#  'hours': 3650,
#  'begging': 1370,
#  'come': 1980,
#  'smoke': 6565,
#  'shoot': 6406,
#  'docs': 2487,
#  'waiting': 7701,
#  'track': 7345,
#  'lighters': 4288,
#  'messages': 4655,
#  'recharge': 5908,
#  'hi': 3542,
#  'grasp': 3330,
#  'pretty': 5669,
#  'booty': 1506,
#  'film': 2941,
#  'princess': 5681,
#  'thinking': 7183,
#  '100': 255,
#  'half': 3413,
#  'price': 5675,
#  'line': 4304,
#  'rental': 5982,
#  '0800': 43,
#  '0721072': 25,
#  'housemaid': 3653,
#  'murderer': 4869,
#  'coz': 2134,
#  'murdered': 4868,
#  'th': 7130,
#  'january': 3947,
#  'public': 5759,
#  'govtinstituitions': 3314,
#  'closedincluding': 1933,
#  'officeunderstand': 5151,
#  'cum': 2201,
#  'lost': 4393,
#  'notice': 5069,
#  'driving': 2567,
#  'anyone': 1062,
#  'slower': 6542,
#  'idiot': 3744,
#  'everyone': 2776,
#  'faster': 2887,
#  'maniac': 4533,
#  'directly': 2440,
#  'behind': 1375,
#  'rows': 6118,
#  'alright': 996,
#  'let': 4259,
#  'leaving': 4238,
#  'gumbys': 3385,
#  'cheese': 1839,
#  'pizza': 5488,
#  'dun': 2598,
#  'ah': 932,
#  'eating': 2628,
#  'ranjith': 5847,
#  'drpd': 2574,
#  'deeraj': 2324,
#  'deepak': 2321,
#  '5min': 613,
#  'hold': 3594,
#  'others': 5258,
#  'probably': 5700,
#  'early': 2613,
#  'aiyah': 952,
#  'improve': 3786,
#  'bringing': 1575,
#  'galileo': 3157,
#  'dobby': 2482,
#  'todays': 7274,
#  'vodafone': 7661,
#  'numbers': 5102,
#  'ending': 2699,
#  '4882': 558,
#  'selected': 6291,
#  'receive': 5900,
#  '350': 488,
#  'award': 1237,
#  'matches': 4561,
#  '09064019014': 210,
#  'mrng': 4822,
#  'quit': 5806,
#  'yet': 8105,
#  'hmmm': 3578,
#  'jazz': 3957,
#  'yogasana': 8114,
#  'oso': 5256,
#  'em': 2680,
#  'den': 2346,
#  'xavier': 8046,
#  'told': 7284,
#  'secret': 6268,
#  'admirer': 881,
#  'looking': 4380,
#  'ufind': 7456,
#  'rreveal': 6125,
#  'thinks': 7184,
#  'specialcall': 6675,
#  '09058094594': 178,
#  'hr': 3666,
#  'b4': 1248,
#  'prepare': 5652,
#  '500': 588,
#  'unclaimed': 7478,
#  '09066368327': 229,
#  'closingdate040902': 1936,
#  'claimcode': 1905,
#  'm39m51': 4467,
#  '150pmmorefrommobile2bremovedmobypobox734ls27yf': 321,
#  'started': 6765,
#  'requests': 6002,
#  'pain': 5314,
#  'bed': 1355,
#  'double': 2527,
#  'coins': 1959,
#  'factory': 2850,
#  'gotta': 3310,
#  'nitros': 5011,
#  'weirdo': 7799,
#  'voucher': 7671,
#  'holder': 3595,
#  'airport': 949,
#  'lounge': 4403,
#  'passes': 5368,
#  'using': 7573,
#  '08704439680': 80,
#  'booking': 1500,
#  'quote': 5812,
#  'night': 4991,
#  'hm': 3574,
#  'morning': 4795,
#  'headache': 3468,
#  'major': 4509,
#  'roles': 6100,
#  'community': 1995,
#  'outreach': 5276,
#  'rock': 6092,
#  'mel': 4618,
#  'wifehow': 7861,
#  'murder': 4867,
#  'exactly': 2793,
#  'alex': 970,
#  'knowwait': 4137,
#  'check': 1830,
#  'tiwary': 7255,
#  'rcbbattle': 5860,
#  'bang': 1285,
#  'kochi': 4141,
#  'remind': 5971,
#  'shall': 6360,
#  'omw': 5191,
#  'tampa': 7031,
#  'west': 7818,
#  'palm': 5321,
#  'hear': 3478,
#  'happened': 3435,
#  'chuckin': 1895,
#  'red': 5923,
#  'green': 3345,
#  'black': 1442,
#  'trainners': 7352,
#  'save': 6214,
#  'carryin': 1750,
#  'bac': 1262,
#  'train': 7350,
#  'settling': 6336,
#  'whats': 7829,
#  'happenin': 3436,
#  'wit': 7897,
#  'ola': 5181,
#  'hows': 3661,
#  'paper': 5334,
#  'dream': 2550,
#  'partner': 5358,
#  'career': 1733,
#  'flyng': 3017,
#  'start': 6764,
#  'horo': 3634,
#  'followed': 3025,
#  'star': 6758,
#  'sign': 6454,
#  'aries': 1129,
#  'sky': 6512,
#  'quite': 5807,
#  'dark': 2253,
#  'raining': 5826,
#  'excuse': 2801,
#  'run': 6147,
#  'rite': 6082,
#  'hee': 3493,
#  'project': 5722,
#  'centre': 1788,
#  'splashmobile': 6702,
#  'choose': 1882,
#  '1000s': 260,
#  'gr8': 3317,
#  'tones': 7300,
#  'wk': 7906,
#  'subscrition': 6896,
#  'costing': 2107,
#  '300p': 472,
#  'credit': 2158,
#  'kick': 4088,
#  'enjoy': 2710,
#  'beautiful': 1346,
#  'comes': 1984,
#  'hunt': 3705,
#  'waste': 7739,
#  'goodmorning': 3292,
#  'staying': 6782,
#  'afternoon': 912,
#  'onwords': 5209,
#  'mtnl': 4842,
#  'problem': 5701,
#  'mumbai': 4857,
#  'cannt': 1717,
#  'listen': 4322,
#  'rd': 5863,
#  'private': 5690,
#  '2004': 386,
#  'account': 844,
#  'statement': 6775,
#  '0784987': 38,
#  'shows': 6434,
#  '786': 679,
#  'unredeemed': 7517,
#  'bonus': 1496,
#  'points': 5550,
#  '08719180219': 152,
#  'identifier': 3743,
#  'code': 1956,
#  '45239': 552,
#  'expires': 2825,
#  '060505': 18,
#  'breathing': 1564,
#  'neck': 4936,
#  'bud': 1610,
#  'anyway': 1071,
#  'youd': 8120,
#  'able': 821,
#  'hurt': 3710,
#  'days': 2279,
#  'satanic': 6204,
#  'imposter': 3782,
#  'meneed': 4630,
#  'priceso': 5676,
#  'itmay': 3917,
#  'destiny': 2378,
#  'pray': 5633,
#  'wont': 7933,
#  'trust': 7392,
#  'boy': 1535,
#  'words': 7943,
#  'left': 4241,
#  'sighs': 6452,
#  'goes': 3269,
#  'studying': 6867,
#  'bad': 1267,
#  'eat': 2625,
#  'dinner': 2434,
#  'cousin': 2130,
#  'jot': 4008,
#  'things': 7179,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8174 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.835 / Accuracy: 0.977
