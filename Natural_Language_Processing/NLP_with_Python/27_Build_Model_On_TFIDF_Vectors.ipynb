# %% [markdown]
# ## Compare NLP Techniques: Build Model On TF-IDF Vectors
#
# ### Read In Cleaned Text

# %%
# Load the cleaned training and testing set
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['guaranteed', '32000', 'award', 'maybe', 'eve...
# 1  ['today', 'sorry', 'day', 'ever', 'angry', 'ev...
# 2                   ['wishing', 'wonderful', 'week']
# 3                         ['part', 'checking', 'iq']
# 4                    ['saw', 'messageit', 'k', 'da']

# %%
### Create TF-IDF Vectors

tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'guaranteed': 3422,
#  '32000': 468,
#  'award': 1245,
#  'maybe': 4651,
#  'even': 2799,
#  '1000': 244,
#  'cash': 1774,
#  'claim': 1938,
#  'ur': 7578,
#  'call': 1689,
#  'free': 3118,
#  '0800': 39,
#  '18': 327,
#  'legitimat': 4305,
#  'efreefone': 2684,
#  'number': 5140,
#  'wat': 7783,
#  'think': 7199,
#  'today': 7292,
#  'sorry': 6655,
#  'day': 2315,
#  'ever': 2804,
#  'angry': 1045,
#  'misbehaved': 4767,
#  'hurt': 3750,
#  'plz': 5562,
#  'slap': 6541,
#  'urself': 7588,
#  'bcoz': 1342,
#  'fault': 2928,
#  'im': 3801,
#  'basically': 1316,
#  'good': 3332,
#  'wishing': 7934,
#  'wonderful': 7970,
#  'week': 7826,
#  'part': 5384,
#  'checking': 1860,
#  'iq': 3930,
#  'saw': 6240,
#  'messageit': 4716,
#  'da': 2260,
#  'gonna': 3330,
#  'go': 3303,
#  'get': 3259,
#  'tacos': 7029,
#  'thanks': 7154,
#  'temales': 7113,
#  'thank': 7153,
#  'great': 3388,
#  'oh': 5200,
#  'thats': 7168,
#  'late': 4263,
#  'well': 7844,
#  'night': 5033,
#  'give': 3287,
#  'tomorrow': 7317,
#  'iam': 3764,
#  'going': 3319,
#  'sleep': 6543,
#  'ready': 5911,
#  'moan': 4800,
#  'scream': 6271,
#  'ask': 1171,
#  'around': 1149,
#  'theres': 7185,
#  'lot': 4451,
#  'terms': 7126,
#  'mids': 4737,
#  'nope': 5090,
#  'since': 6495,
#  'ayo': 1254,
#  'travelled': 7395,
#  'forgotten': 3090,
#  'guy': 3442,
#  'finally': 2990,
#  'fyi': 3197,
#  'okay': 5207,
#  'lor': 4443,
#  'still': 6826,
#  'let': 4320,
#  'us': 7589,
#  'ah': 944,
#  'coz': 2172,
#  'know': 4186,
#  'later': 4268,
#  'drop': 2601,
#  'cards': 1748,
#  'box': 1535,
#  'right': 6094,
#  'looking': 4436,
#  'forward': 3101,
#  'sex': 6363,
#  'cuddling': 2230,
#  'two': 7466,
#  'sleeps': 6548,
#  'themobyo': 7178,
#  'yo': 8163,
#  'yohere': 8166,
#  'comes': 2025,
#  'new': 5013,
#  'selection': 6315,
#  'hot': 3681,
#  'downloads': 2569,
#  'members': 4693,
#  'click': 1958,
#  'open': 5254,
#  'next': 5019,
#  'link': 4371,
#  'sent': 6336,
#  'fone': 3068,
#  'much': 4897,
#  'getting': 3266,
#  'driving': 2598,
#  'training': 7378,
#  'timing': 7261,
#  'hoping': 3669,
#  'enjoyed': 2743,
#  'game': 3207,
#  'yesterday': 8153,
#  'ive': 3972,
#  'touch': 7362,
#  'pls': 5555,
#  'fondly': 3067,
#  'bein': 1379,
#  'thot': 7216,
#  'abiola': 821,
#  'yup': 8201,
#  'shd': 6394,
#  'haf': 3452,
#  'ard': 1126,
#  '10': 242,
#  'pages': 5341,
#  'add': 877,
#  'figures': 2977,
#  'ìï': 8224,
#  'got': 3353,
#  'many': 4596,
#  'gandhipuram': 3210,
#  'walk': 7745,
#  'cross': 2209,
#  'cut': 2251,
#  'road': 6112,
#  'side': 6472,
#  'ltgt': 4497,
#  'street': 6862,
#  'turn': 7451,
#  'first': 3013,
#  'lousy': 4461,
#  'run': 6168,
#  'already': 1003,
#  'come': 2022,
#  'back': 1271,
#  'half': 3463,
#  'dead': 2329,
#  'hee': 3543,
#  'hi': 3587,
#  'engagement': 2737,
#  'fixd': 3021,
#  'th': 7150,
#  'month': 4838,
#  'really': 5920,
#  'shocking': 6425,
#  'bthmm': 1622,
#  'njan': 5054,
#  'vilikkamt': 7675,
#  'ws': 8035,
#  'al': 972,
#  'sudn': 6928,
#  'hey': 3581,
#  'mail': 4567,
#  'wait': 7735,
#  'need': 4985,
#  'feel': 2946,
#  'bad': 1274,
#  'lar': 4254,
#  'upto': 7576,
#  '50': 579,
#  'calls': 1713,
#  'standard': 6776,
#  'network': 5006,
#  'charge': 1838,
#  'activate': 868,
#  '9061100010': 787,
#  'wire3net': 7927,
#  '1st4terms': 353,
#  'pobox84': 5578,
#  'm26': 4532,
#  '3uz': 507,
#  'cost': 2142,
#  '150': 294,
#  'min': 4747,
#  'mobcudb': 4802,
#  'leaving': 4298,
#  'soon': 6645,
#  'little': 4390,
#  'exactly': 2831,
#  'anyways': 1084,
#  'far': 2916,
#  'jide': 4029,
#  'study': 6889,
#  'visiting': 7690,
#  'neva': 5009,
#  'worry': 8003,
#  'bout': 1530,
#  'truth': 7426,
#  'lead': 4289,
#  'heart': 3534,
#  'itåõs': 3970,
#  'least': 4293,
#  'unique': 7537,
#  'person': 5457,
#  'like': 4349,
#  'deserve': 2410,
#  'tight': 7246,
#  'morning': 4850,
#  'called': 1704,
#  'one': 5233,
#  'pick': 5495,
#  'phone': 5481,
#  'said': 6192,
#  'ok': 5206,
#  'dear': 2337,
#  'matthew': 4640,
#  'please': 5548,
#  '09063440451': 190,
#  'landline': 4243,
#  'complimentary': 2052,
#  '4lux': 559,
#  'tenerife': 7120,
#  'holiday': 3635,
#  'await': 1242,
#  'collection': 2009,
#  'ppm150': 5658,
#  'sae': 6187,
#  'tcs': 7077,
#  'box334': 1541,
#  'sk38xh': 6526,
#  'university': 7540,
#  'southern': 6674,
#  'california': 1688,
#  'ki': 4137,
#  'deleted': 2383,
#  'contact': 2097,
#  'callsmessagesmissed': 1715,
#  'case': 1773,
#  'guess': 3430,
#  'ill': 3798,
#  'see': 6300,
#  'campus': 1725,
#  'lodge': 4413,
#  'dun': 2628,
#  'say': 6241,
#  'early': 2647,
#  'hor': 3670,
#  'login': 4418,
#  'anything': 1079,
#  'wake': 7742,
#  'wondering': 7971,
#  'forgot': 3089,
#  'take': 7038,
#  'care': 1749,
#  'something': 6628,
#  'grandma': 3377,
#  'done': 2544,
#  'parade': 5366,
#  'somebody': 6620,
#  'named': 4947,
#  'tampa': 7054,
#  'askd': 1172,
#  'question': 5838,
#  'hours': 3688,
#  'answer': 1062,
#  'sister': 6511,
#  'belongs': 1385,
#  'family': 2905,
#  'hope': 3662,
#  'pray': 5672,
#  'herwho': 3575,
#  'fated': 2924,
#  'shoranur': 6434,
#  'train': 7376,
#  'incident': 3829,
#  'lets': 4321,
#  'hold': 3631,
#  'hands': 3476,
#  'together': 7301,
#  'amp': 1028,
#  'fuelled': 3176,
#  'love': 4464,
#  'concern': 2065,
#  'prior': 5723,
#  'grief': 3400,
#  'pain': 5344,
#  'join': 4040,
#  'dis': 2481,
#  'chain': 1821,
#  'pass': 5395,
#  'stop': 6839,
#  'violence': 7680,
#  'women': 7966,
#  'attended': 1205,
#  'nothing': 5107,
#  'youre': 8183,
#  'car': 1744,
#  'hour': 3686,
#  'apeshit': 1089,
#  'dont': 2547,
#  'respond': 6050,
#  'imma': 3807,
#  'assume': 1183,
#  'asleep': 1177,
#  'start': 6785,
#  'calling': 1710,
#  'shit': 6414,
#  'yar': 8121,
#  'tot': 7358,
#  'knew': 4182,
#  'would': 8015,
#  'happen': 3486,
#  'long': 4430,
#  'ago': 940,
#  'forget': 3084,
#  'though': 7217,
#  'beside': 1396,
#  'watching': 7788,
#  'keeping': 4119,
#  'warm': 7771,
#  'iz': 3975,
#  'yellow': 8135,
#  'rose': 6134,
#  'frndship': 3155,
#  'misscall': 4771,
#  'send': 6327,
#  'frndz': 3158,
#  'miss': 4770,
#  '6missed': 653,
#  'marry': 4614,
#  'lover': 4470,
#  'shoot': 6428,
#  'big': 1419,
#  'loads': 4404,
#  'yes': 8141,
#  'completely': 2050,
#  'formclark': 3095,
#  'also': 1009,
#  'utter': 7611,
#  'waste': 7780,
#  'sad': 6186,
#  'story': 6853,
#  'man': 4584,
#  'last': 4260,
#  'bday': 1345,
#  'wife': 7899,
#  'didnt': 2448,
#  'wish': 7930,
#  'parents': 5374,
#  'kids': 4144,
#  'went': 7852,
#  'work': 7986,
#  'colleagues': 2005,
#  'entered': 2749,
#  'cabin': 1677,
#  'pa': 5333,
#  'happy': 3496,
#  'boss': 1521,
#  'felt': 2954,
#  'special': 6691,
#  'lunch': 4511,
#  'invited': 3916,
#  'apartment': 1087,
#  'mind': 4750,
#  'bedroom': 1361,
#  'minute': 4762,
#  'sed': 6299,
#  'sexy': 6366,
#  'mood': 4842,
#  'came': 1721,
#  'minuts': 4764,
#  'latr': 4271,
#  'wid': 7896,
#  'caken': 1682,
#  'kidz': 4145,
#  'friends': 3146,
#  'screaming': 6273,
#  'surprise': 6983,
#  'waiting': 7739,
#  'sofa': 6610,
#  'naked': 4942,
#  'entry': 2757,
#  '250': 391,
#  'weekly': 7830,
#  'comp': 2038,
#  'word': 7981,
#  'enter': 2748,
#  '84128': 730,
#  'tc': 7075,
#  'wwwtextcompcom': 8080,
#  'cust': 2244,
#  '08712405020': 95,
#  'coming': 2029,
#  'funeral': 3187,
#  'home': 3640,
#  'stubborn': 6882,
#  'want': 7764,
#  'hospital': 3676,
#  'kept': 4125,
#  'telling': 7107,
#  'mark': 4605,
#  'weak': 7802,
#  'sucker': 6923,
#  'hospitals': 3677,
#  'suckers': 6924,
#  'sir': 6505,
#  'strange': 6858,
#  '2nd': 432,
#  'bed': 1359,
#  'sweet': 7004,
#  'dreams': 2583,
#  'nicenicehow': 5026,
#  'working': 7990,
#  'den': 2392,
#  'weekdays': 7827,
#  'price': 5713,
#  'haiz': 3462,
#  'cant': 1735,
#  'eat': 2660,
#  'liao': 4326,
#  'nails': 4941,
#  'oso': 5293,
#  'muz': 4927,
#  'finish': 3001,
#  'drivin': 2597,
#  'sms': 6591,
#  'ac': 833,
#  'blind': 1465,
#  'date': 2303,
#  '4u': 572,
#  'rodds1': 6119,
#  '21m': 379,
#  'aberdeen': 818,
#  'united': 7538,
#  'kingdom': 4154,
#  'check': 1858,
#  'httpimg': 3713,
#  'acwicmb3cktz8r74': 874,
#  'dates': 2305,
#  'hide': 3590,
#  'excuses': 2840,
#  'tee': 7097,
#  'lecture': 4300,
#  'cheery': 1866,
#  'bye': 1673,
#  'reply': 6025,
#  'small': 6568,
#  'kid': 4142,
#  'boost': 1512,
#  'secret': 6292,
#  'energy': 2734,
#  'taste': 7062,
#  'fish': 3014,
#  'curry': 2242,
#  'seeing': 6302,
#  'jeremiah': 4018,
#  'problem': 5737,
#  'talk': 7045,
#  'win': 7910,
#  '100': 243,
#  'music': 4920,
#  'gift': 3273,
#  'vouchers': 7712,
#  'every': 2805,
#  'starting': 6788,
#  'txt': 7467,
#  'draw': 2579,
#  '87066': 747,
#  'tscs': 7433,
#  'wwwidewcom': 8062,
#  'skillgame': 6529,
#  '1winaweek': 359,
#  'age16': 932,
#  '150ppermesssubscription': 310,
#  'ummmmmaah': 7507,
#  'returns': 6076,
#  'birthday': 1438,
#  '447801259231': 531,
#  'admirer': 889,
#  'make': 4575,
#  'ufind': 7487,
#  'rreveal': 6149,
#  'thinks': 7203,
#  'specialcall': 6692,
#  '09058094597': 168,
#  'nah': 4939,
#  'perpetual': 5454,
#  'dd': 2327,
#  'customer': 2248,
#  'service': 6350,
#  'representative': 6029,
#  'freephone': 3129,
#  '0808': 50,
#  '145': 291,
#  '4742': 542,
#  '9am11pm': 799,
#  '5000': 581,
#  'prize': 5729,
#  'sea': 6283,
#  'lays': 4283,
#  'rock': 6117,
#  'envelope': 2760,
#  'paper': 5362,
#  'words': 7983,
#  'laid': 4235,
#  'tonight': 7329,
#  'real': 5913,
#  'dogging': 2529,
#  'locations': 4410,
#  'direct': 2477,
#  'mob': 4801,
#  'uks': 7499,
#  'largest': 4258,
#  'txting': 7472,
#  '69888nyt': 643,
#  'ec2a': 2665,
#  '31pmsg150p': 467,
#  'dinner': 2472,
#  'aight': 959,
#  'wats': 7794,
#  'happening': 3490,
#  'left': 4301,
#  'vague': 7619,
#  'inform': 3860,
#  'accounting': 851,
#  'delayed': 2381,
#  'rent': 6011,
#  'discuss': 2492,
#  'housing': 3693,
#  'agency': 935,
#  'renting': 6013,
#  'another': 1059,
#  'place': 5523,
#  'online': 5239,
#  'places': 5527,
#  'usc': 7591,
#  'must': 4922,
#  'normally': 5097,
#  'bathe': 1324,
#  'afternoon': 923,
#  'mah': 4565,
#  'wlcome': 7953,
#  'wonder': 7969,
#  'eaten': 2661,
#  'lion': 4374,
#  'dayexcept': 2318,
#  'saturday': 6232,
#  'sunday': 6952,
#  'lovin': 4475,
#  'life': 4337,
#  'means': 4660,
#  'people': 5438,
#  'world': 7994,
#  'ge': 3239,
#  'enjoy': 2742,
#  'shows': 6457,
#  'diet': 2454,
#  'ate': 1192,
#  'slices': 6554,
#  'pizza': 5521,
#  'ugh': 7489,
#  'always': 1014,
#  'tarot': 7060,
#  'texts': 7147,
#  'find': 2993,
#  'try': 7428,
#  'text': 7139,
#  'chance': 1826,
#  '85555': 740,
#  '16': 322,
#  'msgs': 4883,
#  'wanna': 7762,
#  'chat': 1847,
#  'things': 7198,
#  'bored': 1515,
#  'etc': 2785,
#  'ring': 6098,
#  'nose': 5101,
#  'essay': 2781,
#  'xx': 8102,
#  'tease': 7092,
#  'cry': 2218,
#  'end': 2726,
#  'die': 2451,
#  'keep': 4118,
#  'grave': 3384,
#  'stupid': 6898,
#  'nice': 5025,
#  'bslvyl': 1617,
#  'lol': 4425,
#  'mad': 4549,
#  'woke': 7962,
#  'gave': 3226,
#  'aiyar': 967,
#  'tell': 7106,
#  'message': 4714,
#  'perumbavoor': 5464,
#  'poyyarikaturkolathupalayamunjalur': 5653,
#  'posterode': 5638,
#  'meet': 4673,
#  'fren': 3133,
#  'wan': 7759,
#  'rite': 6109,
#  'thursday': 7237,
#  'yeah': 8128,
#  'sure': 6976,
#  'thing': 7196,
#  'orh': 5286,
#  'believe': 1380,
#  'specialisation': 6694,
#  'slave': 6542,
#  'labor': 4224,
#  'look': 4432,
#  'sha': 6372,
#  'cos': 2140,
#  'shakara': 6378,
#  'beggar': 1371,
#  'happiness': 3495,
#  'selected': 6314,
#  'alright': 1005,
#  'tylers': 7478,
#  'minor': 4758,
#  'crisis': 2206,
#  'sooner': 6647,
#  'thought': 7218,
#  'asap': 1164,
#  'table': 7024,
#  'booked': 1505,
#  'eight': 2693,
#  'cud': 2227,
#  'ppl': 5654,
#  'gona': 3326,
#  'bit': 1440,
#  'l8': 4216,
#  'buses': 1655,
#  'hav': 3513,
#  'gon': 3325,
#  'past': 5404,
#  'full': 3180,
#  'waitin': 7738,
#  'pete': 5467,
#  'remember': 5996,
#  'beads': 1346,
#  'knw': 4192,
#  'drink': 2590,
#  'milk': 4742,
#  'jetton': 4026,
#  'ave': 1233,
#  'chicken': 1886,
#  'broth': 1604,
#  'ramen': 5876,
#  'unless': 7542,
#  'ho': 3625,
#  'time': 7254,
#  'use': 7593,
#  'type': 7479,
#  'moves': 4868,
#  'however': 3697,
#  '6hrs': 651,
#  'doctor': 2520,
#  'someonone': 6624,
#  'trying': 7429,
#  'via': 7656,
#  'dating': 2306,
#  'could': 2152,
#  'mobile': 4803,
#  '09064015307': 197,
#  'box334sk38ch': 1542,
#  'short': 6437,
#  'cute': 2252,
#  'ithis': 3952,
#  'created': 2191,
#  'web': 7812,
#  'page': 5340,
#  'wwwasjesuscom': 8050,
#  'read': 5907,
#  'wrote': 8034,
#  'opinions': 5261,
#  'friend': 3144,
#  '11': 263,
#  'eh': 2691,
#  'leh': 4307,
#  'din': 2469,
#  'msg': 4880,
#  'tv': 7456,
#  'office': 5184,
#  'balance': 1287,
#  '600': 617,
#  'complete': 2049,
#  'landmark': 4246,
#  'bob': 1492,
#  'barry': 1312,
#  'ben': 1389,
#  '83738': 726,
#  'luck': 4502,
#  '449050000301': 533,
#  '2000': 365,
#  '09050000301': 148,
#  'text82228': 7140,
#  'ringtones': 6104,
#  'logos': 4422,
#  'games': 3208,
#  'wwwtxt82228com': 8085,
#  'questions': 5840,
#  'infotxt82228couk': 3864,
#  'mums': 4911,
#  'repent': 6019,
#  'set': 6354,
#  '09096102316': 233,
#  'cum': 2234,
#  '2moro': 424,
#  'luv': 4516,
#  'jane': 3997,
#  'callså': 1716,
#  '1minmoremobsemspobox45po139wa': 348,
#  'prashanthettans': 5671,
#  'mother': 4856,
#  'passed': 5397,
#  'away': 1247,
#  'wnevr': 7958,
#  'wana': 7761,
#  'fal': 2897,
#  'vth': 7718,
#  'books': 1509,
#  'fals': 2902,
#  'yen': 8137,
#  'madodu': 4555,
#  'nav': 4968,
#  'pretsorginta': 5706,
#  'nammanna': 4949,
#  'pretsovru': 5707,
#  'important': 3814,
#  'alwa': 1013,
#  'gud': 3424,
#  'eveb': 2797,
#  'mostly': 4855,
#  'sports': 6740,
#  'typelyk': 7480,
#  'footblcrckt': 3075,
#  'wanted': 7766,
#  'scold': 6259,
#  'yest': 8152,
#  'zhong': 8210,
#  'se': 6282,
#  'qing': 5831,
#  'b4': 1256,
#  'act': 862,
#  'couldnt': 2154,
#  'worse': 8007,
#  'exam': 2832,
#  'march': 4601,
#  'hun': 3734,
#  'comin': 2028,
#  '2nitetell': 436,
#  'every1': 2806,
#  'ava': 1227,
#  'goodtimeoli': 3346,
#  'rang': 5882,
#  'melnite': 4689,
#  'ifink': 3790,
#  'mite': 4783,
#  'sortedbut': 6660,
#  'il': 3796,
#  'explain': 2861,
#  'everythin': 2813,
#  'monl8rsx': 4833,
#  'tick': 7241,
#  'babe': 1262,
#  'hai': 3456,
#  'present': 5698,
#  'rajitha': 5871,
#  'raj': 5867,
#  'ranju': 5885,
#  'asked': 1173,
#  '3mobile': 498,
#  '0870': 60,
#  'chatlines': 1850,
#  'inclu': 3830,
#  'mins': 4759,
#  'india': 3847,
#  'servs': 6353,
#  'l8er': 4217,
#  'mega': 4680,
#  'bill': 1423,
#  'giv': 3286,
#  'bailiff': 1283,
#  'due': 2624,
#  'days': 2320,
#  '800': 690,
#  'princess': 5719,
#  'thinking': 7202,
#  'meant': 4661,
#  'middle': 4735,
#  'urgent': 7581,
#  'weekends': 7829,
#  '900': 786,
#  '09061701939': 180,
#  'code': 1994,
#  's89': 6179,
#  'valid': 7625,
#  '12hrs': 282,
#  'buzy': 1665,
#  'defer': 2372,
#  'admission': 890,
#  'til': 7251,
#  'semester': 6323,
#  'wasnt': 7778,
#  'available': 1229,
#  'washob': 7777,
#  'nobbing': 5063,
#  'nickey': 5028,
#  'platt': 5537,
#  'instead': 3888,
#  'rem': 5992,
#  'silver': 6487,
#  'thk': 7208,
#  'black': 1447,
#  'freemsg': 3125,
#  'records': 5950,
#  'indicate': 3851,
#  'may': 4649,
#  'entitled': 2754,
#  '3750': 483,
#  'pounds': 5647,
#  'accident': 842,
#  'opt': 5268,
#  'leave': 4296,
#  'chase': 1844,
#  'shes': 6401,
#  'crossing': 2210,
#  'hahahause': 3454,
#  'brain': 1558,
#  'mum': 4906,
#  'robinson': 6115,
#  'tho': 7214,
#  'sucks': 6925,
#  'cook': 2119,
#  'whole': 7889,
#  'electricity': 2704,
#  'hungry': 3738,
#  'winner': 7920,
#  'specially': 6696,
#  'receive': 5933,
#  'flights': 3036,
#  'inc': 3826,
#  'speak': 6689,
#  'live': 4391,
#  'operator': 5259,
#  '0871277810810': 99,
#  'dude': 2622,
#  'lotta': 4456,
#  'corvettes': 2139,
#  'lately': 4266,
#  'cds': 1799,
#  'congratulations': 2083,
#  'awarded': 1246,
#  '500': 580,
#  'cd': 1797,
#  '125': 278,
#  'freeentry': 3121,
#  'wkly': 7949,
#  'xt': 8100,
#  'tncs': 7285,
#  'wwwldewcom1win150ppmx3age16': 8064,
#  'openings': 5257,
#  'room': 6129,
#  'thanksgiving': 7155,
#  'without': 7939,
#  'upcharge': 7558,
#  'weekend': 7828,
#  'wot': 8011,
#  'todays': 7297,
#  'horny': 3672,
#  'town': 7368,
#  'fun': 3183,
#  'netcollex': 5003,
#  'ltd': 4492,
#  '08700621170150p': 61,
#  'per': 5440,
#  'desperate': 2414,
#  'armand': 1142,
#  'death': 2348,
#  'note': 5104,
#  'says': 6245,
#  'robs': 6116,
#  'avenge': 1234,
#  'hows': 3699,
#  'figure': 2976,
#  'years': 8131,
#  'buy': 1662,
#  'meat': 4664,
#  'lovers': 4473,
#  'supreme': 6973,
#  'private': 5727,
#  '2003': 367,
#  'account': 850,
#  'statement': 6794,
#  '07815296484': 33,
#  'unredeemed': 7548,
#  'sim': 6488,
#  'points': 5587,
#  '08718738001': 135,
#  'identifier': 3783,
#  '41782': 521,
#  'expires': 2859,
#  '181104': 329,
#  'grandmas': 3378,
#  'hungover': 3737,
#  'sat': 6224,
#  'messageno': 4718,
#  'responcewhat': 6049,
#  'happend': 3487,
#  'uve': 7615,
#  'xchat': 8094,
#  'final': 2988,
#  'attempt': 1202,
#  '86688': 744,
#  '150pmsgrcvdhgsuite3422landsroww1j6hl': 307,
#  'ldn': 4286,
#  'yrs': 8194,
#  'opinion': 5260,
#  'abt': 829,
#  'character': 1836,
#  'shall': 6382,
#  'pickle': 5498,
#  'worth': 8009,
#  'discount': 2490,
#  'voucherstext': 7713,
#  '85023': 735,
#  'nowsavamobmember': 5126,
#  'offers': 5182,
#  'cs': 2220,
#  '08717898035': 121,
#  '300': 455,
#  'sub': 6904,
#  'remove': 6005,
#  'actually': 873,
#  'fuck': 3169,
#  'whatever': 7869,
#  'excuse': 2838,
#  'point': 5586,
#  'january': 3998,
#  'dearly': 2342,
#  'lots': 4454,
#  'used': 7594,
#  'ones': 5235,
#  'model': 4813,
#  'doesnt': 2523,
#  'help': 3557,
#  'youi': 8175,
#  'bring': 1590,
#  'hell': 3549,
#  'match': 4624,
#  'haha': 3453,
#  'found': 3103,
#  'piece': 5505,
#  'priscillas': 5725,
#  'bowl': 1533,
#  'oops': 5253,
#  'till': 7252,
#  'bus': 1653,
#  'cuddle': 2228,
#  'strong': 6875,
#  'arms': 1145,
#  'erm': 2766,
#  'woodland': 7975,
#  'avenue': 1236,
#  'somewhere': 6634,
#  'parish': 5378,
#  'magazine': 4560,
#  'telephone': 7103,
#  'hiya': 3610,
#  'naughty': 4966,
#  'bought': 1527,
#  'clothes': 1971,
#  'shopping': 6431,
#  'kind': 4150,
#  'castor': 1782,
#  'uniform': 7534,
#  'alone': 1001,
#  'dessert': 2416,
#  'suntec': 6958,
#  'shuhui': 6463,
#  'change': 1828,
#  'steamboat': 6808,
#  'noe': 5067,
#  'eerie': 2680,
#  'nokia': 5075,
#  'tones': 7322,
#  'rply': 6147,
#  'tone': 7321,
#  'title': 7270,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8232 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to array?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RF Classifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)
y_pred[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
# Evaluate the prediction of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score, accuracy_score

acc = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print(f"Precision: {round(precision, 3)} / Recall: {round(recall, 3)} / Accuracy: {round(acc, 3)}")
# Out:
# Precision: 1.0 / Recall: 0.774 / Accuracy: 0.969
