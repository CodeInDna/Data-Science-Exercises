# %%
import pandas as pd

# %%
df = pd.read_csv('AZDIAS_Subset_1.csv',sep = ';',index_col=0)
l = len(df)
l/2
df1 = df[:int(l/2)]
df2 = df[int(l/2):]

# %%
df1.to_csv("AZDIAS_Subset_11.csv")
df2.to_csv("AZDIAS_Subset_12.csv")

# %%
df = pd.read_csv('AZDIAS_Subset_2.csv',sep = ';',index_col=0)
l = len(df)
l/2
df1 = df[:int(l/2)]
df2 = df[int(l/2):]

# %%
df1.to_csv("AZDIAS_Subset_21.csv")
df2.to_csv("AZDIAS_Subset_22.csv")

# %%
df.head(int(l/2))
# Out:
#         AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0             -1                     2          1            2.0
# 1             -1                     1          2            5.0
# 2             -1                     3          2            3.0
# 3              2                     4          2            2.0
# 4             -1                     3          1            5.0
# ...          ...                   ...        ...            ...
# 222800        -1                     1          2            6.0
# 222801         1                     3          2            4.0
# 222802        -1                     1          2            6.0
# 222803        -1                     3          2            4.0
# 222804        -1                     3          1            5.0
#
#         FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                       3              4                 3               5
# ...

# %%
l
# Out:
# 445610

# %%
l/2
# Out:
# 222805.0

# %%
df
# Out:
#         AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0             -1                     2          1            2.0
# 1             -1                     1          2            5.0
# 2             -1                     3          2            3.0
# 3              2                     4          2            2.0
# 4             -1                     3          1            5.0
# ...          ...                   ...        ...            ...
# 445605         3                     1          1            1.0
# 445606         2                     3          1            5.0
# 445607         2                     4          1            1.0
# 445608        -1                     4          2            2.0
# 445609        -1                     1          1            4.0
#
#         FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                       3              4                 3               5
# ...

# %%
df[:int(l/2)]
# Out:
#         AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0             -1                     2          1            2.0
# 1             -1                     1          2            5.0
# 2             -1                     3          2            3.0
# 3              2                     4          2            2.0
# 4             -1                     3          1            5.0
# ...          ...                   ...        ...            ...
# 222800        -1                     1          2            6.0
# 222801         1                     3          2            4.0
# 222802        -1                     1          2            6.0
# 222803        -1                     3          2            4.0
# 222804        -1                     3          1            5.0
#
#         FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                       3              4                 3               5
# ...
