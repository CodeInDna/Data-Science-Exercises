# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tests as t
import progressbar
from scipy.sparse import csr_matrix
from IPython.display import HTML


# %matplotlib inline

# Read in the datasets
movies = pd.read_csv('./Datasets/movies_clean.csv')
reviews = pd.read_csv('./Datasets/reviews_clean.csv')[:2000]

del movies['Unnamed: 0']
del reviews['Unnamed: 0']

print(reviews.head())
# Out:
#    user_id  movie_id  rating   timestamp            date_time
# 0        1    114508       8  1381006850  2013-10-06 02:30:50
# 1        2    358273       9  1579057827  2020-01-15 08:40:27
# 2        2  10039344       5  1578603053  2020-01-10 02:20:53
# 3        2   6751668       9  1578955697  2020-01-14 04:18:17
# 4        2   7131622       8  1579559244  2020-01-21 03:57:24

# %%
user_items = reviews[['user_id', 'movie_id', 'rating']]
user_items.head()
# Out:
#    user_id  movie_id  rating
# 0        1    114508       8
# 1        2    358273       9
# 2        2  10039344       5
# 3        2   6751668       9
# 4        2   7131622       8

# %%
user_by_movie = user_items.groupby(['user_id', 'movie_id'])['rating'].max().unstack()
user_by_movie.head()
# Out:
# movie_id  33477     37059     38650     39628     40522     41716     \
# user_id
# 1              NaN       NaN       NaN       NaN       NaN       NaN
# 2              NaN       NaN       NaN       NaN       NaN       NaN
# 3              NaN       NaN       NaN       NaN       NaN       NaN
# 4              NaN       NaN       NaN       NaN       NaN       NaN
# 5              NaN       NaN       NaN       NaN       NaN       NaN
#
# movie_id  42332     45152     45591     45607     ...  8579674   8632862   \
# user_id                                           ...
# 1              NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2              NaN       NaN       NaN       NaN  ...      10.0       NaN
# 3              NaN       NaN       NaN       NaN  ...       NaN       NaN
# 4              NaN       NaN       NaN       NaN  ...       NaN       NaN
# 5              NaN       NaN       NaN       NaN  ...       NaN       NaN
#
# movie_id  8772262   9086228   9243946   9495224   9541602   10039344  \
# user_id
# 1              NaN       NaN       NaN       NaN       NaN       NaN
# 2              NaN       NaN       NaN       NaN       NaN       5.0
# 3              NaN       NaN       NaN       NaN       NaN       NaN
# 4              NaN       NaN       NaN       NaN       NaN       NaN
# 5              NaN       NaN       NaN       NaN       NaN       NaN
#
# movie_id  10367276  10648440
# user_id
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# 5              NaN       NaN
#
# [5 rows x 1391 columns]

# %%
def movies_watched(user_id):
    movies = user_by_movie.loc[user_id][user_by_movie.loc[user_id].isnull()==False].index.values
    return movies

# %%
def create_user_movie_dict():
    n_users = user_by_movie.shape[0]
    
    user_id_movies = dict()
    
    cnter = 0
    bar = progressbar.ProgressBar(maxval=n_users+1, widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    
    for user_id in range(1, n_users+1):
        movies = movies_watched(user_id)
        user_id_movies[user_id] = movies
        cnter += 1
        bar.update(cnter)
        
    bar.finish()
        
    return user_id_movies
        
movies_seen = create_user_movie_dict()
# Out:
# [========================================================================] 100%

# %%
def create_movies_to_analyze(movies_seen, lower_bound):
    
    movies_to_analyze = dict()
    
    for user_id, movies in movies_seen.items():
        if len(movies) > lower_bound:
            movies_to_analyze[user_id] = movies
    return movies_to_analyze

movies_to_analyze = create_movies_to_analyze(movies_seen, 2)

# %%
movies_to_analyze
# Out:
# {2: array([  358273,  6751668,  7131622,  7975244,  7984734,  8579674,
#         10039344], dtype=int64),
#         5095030, 5104604, 5109784, 5140878, 5160938, 5164214, 5164432,
#         5168192, 5179598, 5186714, 5220122, 5294550, 5304464, 5390504,
#         5437928, 5439796, 5442430, 5450984, 5461944, 5462602, 5463162,
#         5478478, 5523010, 5556144, 5580036, 5580266, 5580390, 5592248,
#         5635086, 5639354, 5639446, 5649144, 5651050, 5688932, 5700176,
#         5700672, 5715874, 5716464, 5719700, 5726616, 5776858, 5814060,
#         5816682, 5824900, 5848272, 5850440, 5886046, 5886440, 5929776,
#         5960374, 6063090, 6139732, 6146586, 6155172, 6225520, 6257174,
#         6266538, 6294822, 6303866, 6306064, 6320628, 6398184, 6483364,
#         6499752, 6513120, 6565702, 6628394, 6663582, 6679794, 6751668,
#         6802308, 6823368, 6852872, 6857112, 6859762, 6865690, 6911608,
#         6938828, 6952960, 6966692, 6998518, 7008872, 7235270, 7286456,
#         7349662, 7401588, 7545524, 7549996, 7645780, 7668870, 7784604,
#         7959026, 8075192, 8254556, 8267604, 8350360, 8632862, 9495224],
#        dtype=int64),
#  97: array([  68646,   71562,   99674,  101414,  482571,  816711, 1343092,
#         1392214, 1490017, 1690953, 1723121, 1921064, 2234155, 2395427],
#        dtype=int64),
#  98: array([  56576,   69121,   80474,   93229, 1045658, 1074638, 1430626,
#         1549572, 1549920, 1570989, 1583421, 1602613, 1637725, 1907639,
#         1907668, 2101441, 2390361], dtype=int64),
#  100: array([  61418,   83658,   95327,   95765,   96283,  104652,  119698,
#          156887,  167261,  253474,  265666,  268978,  364569,  407887,
#          424227,  443706,  451279,  477348,  490215,  816692,  974015,
#         1014763, 1212428, 1241317, 1242422, 1255953, 1302006, 1365050,
#         1365519, 1386697, 1392190, 1392214, 1560220, 1590193, 1605783,
#         1638002, 1677720, 1723811, 1763303, 1790809, 1825683, 1856101,
#         1860357, 1895587, 1924396, 1959563, 1979376, 2084970, 2179121,
#         2182972, 2250912, 2283362, 2359024, 2380307, 2381111, 2543164,
#         2543472, 2674426, 2737304, 2771200, 2948356, 2980516, 3076658,
#         3183660, 3315342, 3397884, 3402236, 3470600, 3498820, 3501632,
#         3521126, 3553976, 3731562, 3783958, 3890160, 3896198, 4034228,
#         4154664, 4196776, 4272866, 4425200, 4649466, 4669986, 4758646,
#         4912910, 5013056, 5027774, 5083738, 5104604, 5311514, 5439796,
#         5463162, 5580036, 5580390, 5715874, 5776858, 5791536, 5816374],
#        dtype=int64)}

# %%
def compute_corr_pearson(user1, user2):
    movies1 = movies_to_analyze[user1]
    movies2 = movies_to_analyze[user2]
    
    sim_mov = np.intersect1d(movies1, movies2, assume_unique=True)
    
    if len(sim_mov) > 0:
        
        df = user_by_movie.loc[(user1, user2), sim_mov]
    
        dist = np.linalg.norm(df.loc[user1] - df.loc[user2])
        
        return dist

# %%
corr_df = []
corr = 0
for user1 in movies_to_analyze:
    for user2 in movies_to_analyze:
        dist = compute_corr_pearson(user1, user2)
        if dist is not None:
            corr_df.append({'user1':user1, 'user2':user2, 'euc_dist':dist})

# %%
df_dist = pd.DataFrame(corr_df)

# %%
user_by_movie.loc[61][user_by_movie.loc[61].isnull() == False].count()
# Out:
# 121

# %%
def find_closest_distance(user):
    closest_neighbor = df_dist[df_dist['user1'] == user].sort_values(by='euc_dist').iloc[1:]['user2']
    closest_neighbor = np.array(closest_neighbor)
    return closest_neighbor
print(find_closest_distance(11))
# Out:
# [41 74 12 91  2 61 95]

# %%
def movies_liked(user_id, min_rating=7):
    return np.array(user_items.query('user_id == @user_id and rating >= @min_rating')['movie_id'])
movies_liked(11)
# Out:
# array([1282140, 2388771, 4477536, 6450804, 7286456, 8201170, 8579674],
#       dtype=int64)

# %%
def movie_names(movie_ids):
    movie_lst = movies[movies['movie_id'].isin(movie_ids)]['movie']
    return list(movie_lst)
movie_names(movies_liked(11))
# Out:
# ['Easy A (2010)',
#  'Mowgli (2018)',
#  'Fifty Shades Freed (2018)',
#  'Terminator: Dark Fate (2019)',
#  'Joker (2019)',
#  'The Perfect Date (2019)',
#  '1917 (2019)']

# %%
def make_recommendations(user, num_recs=10):
    # movies_seen by user (we don't want to recommend these)
    movies_seen = movies_watched(user)
    closest_neighbors = find_closest_distance(user)
    
    # Keep the recommended movies here
    recs = np.array([])
    
    # Go through the neighbors and identify movies they like the user hasn't seen
    for neighbor in closest_neighbors:
        neighbs_likes = movies_liked(neighbor)
        
        #Obtain recommendations for each neighbor
        new_recs = np.setdiff1d(neighbs_likes, movies_seen, assume_unique=True)
        
        # Update recs with new recs
        recs = np.unique(np.concatenate([new_recs, recs], axis=0))
        
        # If we have enough recommendations exit the loop
        if len(recs) > num_recs-1:
            break
    
    # Pull movie titles using movie ids
    recommendations = movie_names(recs)
    
    return recommendations[:10]

# %%
make_recommendations(2)
# Out:
# ['The Deer Hunter (1978)',
#  'Fahrenheit 451 (2018)',
#  'A Walk Among the Tombstones (2014)',
#  'Jurassic World (2015)',
#  'Shazam! (2019)',
#  'Ex Machina (2014)',
#  'World War Z (2013)',
#  'Lone Survivor (2013)',
#  'Cold in July (2014)',
#  'Broken City (2013)']

# %%
def all_recs(num_recs=10):
    users = np.unique(df_dist['user1'])
    n_users = users.shape[0]
    
    all_recs = dict()
    
    center = 0
    bar = progressbar.ProgressBar(maxval=n_users+1, widgets=[progressbar.Bar('=','[',']'),' ', progressbar.Percentage()])
    bar.start()
    
    for user in users:
        center += 1
        bar.update(center)
        
        recs = make_recommendations(user, num_recs)
        all_recs[user] = recs
        
    bar.finish()
    return all_recs

# %%
all_recs()
# Out:
# [========================================================================] 100%
# {2: ['The Deer Hunter (1978)',
#   'Fahrenheit 451 (2018)',
#   'A Walk Among the Tombstones (2014)',
#   'Jurassic World (2015)',
#   'Shazam! (2019)',
#   'Ex Machina (2014)',
#   'World War Z (2013)',
#   'Lone Survivor (2013)',
#   'Cold in July (2014)',
#   'Broken City (2013)'],
#  3: ['The Godfather: Part II (1974)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'The Fly (1986)',
#   'A Few Good Men (1992)',
#   'Heat (1995)',
#   'Meet Joe Black (1998)',
#   'Rush Hour (1998)',
#   'Fight Club (1999)',
#   'Sleepy Hollow (1999)'],
#  4: ['The Godfather (1972)',
#   'The Godfather: Part II (1974)',
#   'The Godfather: Part III (1990)',
#   'Beauty and the Beast (1991)',
#   'The Prestige (2006)',
#   'World War Z (2013)',
#   'Prisoners (2013)',
#   'Despicable Me 2 (2013)',
#   "We're the Millers (2013)",
#   'Pompeii (2014)'],
#  5: ['Rebel Without a Cause (1955)',
#   'What Ever Happened to Baby Jane? (1962)',
#   'Westworld (1973)',
#   'Star Wars (1977)',
#   'The Shining (1980)',
#   'An American Werewolf in London (1981)',
#   'Vacation (1983)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Gremlins (1984)',
#   'A Nightmare on Elm Street (1984)'],
#  6: ['The Godfather: Part II (1974)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'The Fly (1986)',
#   'A Few Good Men (1992)',
#   'Heat (1995)',
#   'Meet Joe Black (1998)',
#   'Rush Hour (1998)',
#   'Fight Club (1999)',
#   'Sleepy Hollow (1999)'],
#  7: ['Ladri di biciclette (1948)',
#   '12 Angry Men (1957)',
#   'Cinema Paradiso (1988)',
#   'Requiem for a Dream (2000)',
#   'Million Dollar Baby (2004)',
#   'Fantastic Beasts and Where to Find Them (2016)',
#   'Kong: Skull Island (2017)',
#   "Don't Breathe (2016)",
#   'Dunkirk (2017)',
#   'Happy Death Day (2017)'],
#  11: ['Fight Club (1999)',
#   'V for Vendetta (2005)',
#   'Death Race (2008)',
#   'The Equalizer (2014)',
#   'The International (2009)',
#   'The Darkest Hour (2011)',
#   'Aloha (2015)',
#   'Gangster Squad (2013)',
#   'Passengers (2016)',
#   'Tomb Raider (2018)'],
#  12: ['Walk the Line (2005)',
#   'Easy A (2010)',
#   'Mowgli (2018)',
#   'Fifty Shades Freed (2018)',
#   'Terminator: Dark Fate (2019)',
#   'Gisaengchung (2019)',
#   'Once Upon a Time ...in Hollywood (2019)',
#   'Joker (2019)',
#   'The Lighthouse (2019)',
#   'The Perfect Date (2019)'],
#  15: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)'],
#  18: [],
#  19: ['Mad Max (1979)',
#   'Mad Max 2 (1981)',
#   'The Addams Family (1991)',
#   'The Mummy (1999)',
#   'The Lord of the Rings: The Fellowship of the Ring (2001)',
#   'The Lord of the Rings: The Return of the King (2003)',
#   'The Lord of the Rings: The Two Towers (2002)',
#   'The Haunting (1999)',
#   'The Mummy Returns (2001)',
#   'Dodgeball: A True Underdog Story (2004)'],
#  21: ["Singin' in the Rain (1952)",
#   '12 Angry Men (1957)',
#   'The Godfather (1972)',
#   'Star Wars (1977)',
#   'Hair (1979)',
#   'Star Wars: Episode V - The Empire Strikes Back (1980)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Goodfellas (1990)',
#   'Batman: Mask of the Phantasm (1993)',
#   'LÃ©on (1994)'],
#  27: ['Barry Lyndon (1975)',
#   'Mammoth (2009)',
#   'The Ides of March (2011)',
#   'The Hobbit: The Desolation of Smaug (2013)',
#   'The Imitation Game (2014)',
#   'Spring Breakers (2012)',
#   'Before Midnight (2013)',
#   'Tesis sobre un homicidio (2013)',
#   'Drinking Buddies (2013)',
#   'In a World... (2013)'],
#  30: ['Star Wars: Episode V - The Empire Strikes Back (1980)',
#   'Scarface (1983)',
#   'The Breakfast Club (1985)',
#   'Ace Ventura: Pet Detective (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'Office Space (1999)',
#   '8 Mile (2002)',
#   'The Machinist (2004)',
#   'The Terminal (2004)'],
#  38: ['The Godfather: Part II (1974)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'The Fly (1986)',
#   'A Few Good Men (1992)',
#   'Heat (1995)',
#   'Meet Joe Black (1998)',
#   'Rush Hour (1998)',
#   'Fight Club (1999)',
#   'Sleepy Hollow (1999)'],
#  41: ["Breakfast at Tiffany's (1961)",
#   'Hadashi no Gen (1983)',
#   'SamÃ¢ uÃ´zu (2009)',
#   'Jageun yeonmot (2009)',
#   'The Glass Castle (2017)',
#   'Mandariinid (2013)',
#   'Jobanni no shima (2014)',
#   'Free Fire (2016)',
#   'The Founder (2016)',
#   'Kokoro ga sakebitagatterunda. (2015)'],
#  42: [],
#  44: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)'],
#  48: ['Jurassic World (2015)',
#   'Ant-Man (2015)',
#   'Deadpool (2016)',
#   'Broken (2012)',
#   'Warm Bodies (2013)',
#   'Spectre (2015)',
#   'Star Wars: Episode VII - The Force Awakens (2015)',
#   'Batman v Superman: Dawn of Justice (2016)',
#   'The Jungle Book (2016)',
#   'X-Men: Apocalypse (2016)'],
#  50: ["Singin' in the Rain (1952)",
#   '12 Angry Men (1957)',
#   'The Godfather (1972)',
#   'Star Wars (1977)',
#   'Hair (1979)',
#   'Star Wars: Episode V - The Empire Strikes Back (1980)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Goodfellas (1990)',
#   'Batman: Mask of the Phantasm (1993)',
#   'LÃ©on (1994)'],
#  51: ['Bonnie and Clyde (1967)',
#   'Blade Runner (1982)',
#   'Hotaru no haka (1988)',
#   'Cinema Paradiso (1988)',
#   'Tonari no Totoro (1988)',
#   'Kurenai no buta (1992)',
#   'Mononoke-hime (1997)',
#   'PÃ¢fekuto burÃ» (1997)',
#   'The Lord of the Rings: The Two Towers (2002)',
#   'The Pianist (2002)'],
#  52: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)',
#   'The Life Aquatic with Steve Zissou (2004)'],
#  53: ['Rebel Without a Cause (1955)',
#   'What Ever Happened to Baby Jane? (1962)',
#   'Westworld (1973)',
#   'Star Wars (1977)',
#   'The Shining (1980)',
#   'An American Werewolf in London (1981)',
#   'Vacation (1983)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Gremlins (1984)',
#   'A Nightmare on Elm Street (1984)'],
#  54: ['The Deer Hunter (1978)',
#   'Fahrenheit 451 (2018)',
#   'A Walk Among the Tombstones (2014)',
#   'Jurassic World (2015)',
#   'Shazam! (2019)',
#   'Ex Machina (2014)',
#   'World War Z (2013)',
#   'Lone Survivor (2013)',
#   'Cold in July (2014)',
#   'Broken City (2013)'],
#  57: ['Come Live with Me (1941)',
#   "It's a Wonderful Life (1946)",
#   'Miracle on 34th Street (1947)',
#   'Cinderella (1950)',
#   'Calamity Jane (1953)',
#   'On the Waterfront (1954)',
#   'Rear Window (1954)',
#   'The Man from Laramie (1955)',
#   'Vertigo (1958)',
#   "Ocean's Eleven (1960)"],
#  58: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'If Only (2004)'],
#  59: ['Alien (1979)',
#   'Aliens (1986)',
#   'No Country for Old Men (2007)',
#   'World War Z (2013)',
#   'The Imaginarium of Doctor Parnassus (2009)',
#   'Looper (2012)',
#   'Now You See Me (2013)',
#   'Dragon Ball Z: Battle of Gods (2013)',
#   'Howl (2015)',
#   'The Green Inferno (2013)'],
#  61: ["Breakfast at Tiffany's (1961)",
#   'Hadashi no Gen (1983)',
#   'SamÃ¢ uÃ´zu (2009)',
#   'Jageun yeonmot (2009)',
#   'Deepwater Horizon (2016)',
#   'The Glass Castle (2017)',
#   'Mandariinid (2013)',
#   'Jobanni no shima (2014)',
#   'Free Fire (2016)',
#   'The Founder (2016)'],
#  62: ['Mad Max (1979)',
#   'Mad Max 2 (1981)',
#   'The Addams Family (1991)',
#   'The Mummy (1999)',
#   'The Lord of the Rings: The Fellowship of the Ring (2001)',
#   'The Lord of the Rings: The Return of the King (2003)',
#   'The Lord of the Rings: The Two Towers (2002)',
#   'The Haunting (1999)',
#   'The Mummy Returns (2001)',
#   'Dodgeball: A True Underdog Story (2004)'],
#  64: ['The Deer Hunter (1978)',
#   'Fahrenheit 451 (2018)',
#   'A Walk Among the Tombstones (2014)',
#   'Jurassic World (2015)',
#   'Shazam! (2019)',
#   'Ex Machina (2014)',
#   'World War Z (2013)',
#   'Lone Survivor (2013)',
#   'Cold in July (2014)',
#   'Broken City (2013)'],
#  66: ['The Deer Hunter (1978)',
#   'Fahrenheit 451 (2018)',
#   'A Walk Among the Tombstones (2014)',
#   'Jurassic World (2015)',
#   'Shazam! (2019)',
#   'Ex Machina (2014)',
#   'World War Z (2013)',
#   'Lone Survivor (2013)',
#   'Cold in July (2014)',
#   'Broken City (2013)'],
#  69: ['Rebel Without a Cause (1955)',
#   'What Ever Happened to Baby Jane? (1962)',
#   'Westworld (1973)',
#   'Star Wars (1977)',
#   'The Shining (1980)',
#   'An American Werewolf in London (1981)',
#   'Vacation (1983)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Gremlins (1984)',
#   'A Nightmare on Elm Street (1984)'],
#  70: ['The Godfather (1972)',
#   'The Godfather: Part II (1974)',
#   'The Godfather: Part III (1990)',
#   'Beauty and the Beast (1991)',
#   'The Prestige (2006)',
#   'The Great Gatsby (2013)',
#   'Prisoners (2013)',
#   'Despicable Me 2 (2013)',
#   "We're the Millers (2013)",
#   'Pompeii (2014)'],
#  73: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)'],
#  74: ['The Grinch (2018)',
#   'Godzilla: King of the Monsters (2019)',
#   'The Secret Life of Pets 2 (2019)',
#   "Ocean's Eight (2018)",
#   'Hotel Transylvania 3: Summer Vacation (2018)',
#   'Eli (2019)',
#   'Doctor Sleep (2019)',
#   'Terminator: Dark Fate (2019)',
#   'Method (2017)',
#   'It Chapter Two (2019)'],
#  78: ['The Damned (1963)',
#   'Prime Cut (1972)',
#   'Brubaker (1980)',
#   'Silver Linings Playbook (2012)',
#   'Skyfall (2012)',
#   'The Pirates! In an Adventure with Scientists! (2012)',
#   'The Last Stand (2013)',
#   'Tiny Furniture (2010)',
#   'Ted (2012)',
#   'Spring Breakers (2012)'],
#  81: ['Rebel Without a Cause (1955)',
#   'What Ever Happened to Baby Jane? (1962)',
#   'Westworld (1973)',
#   'Star Wars (1977)',
#   'The Shining (1980)',
#   'An American Werewolf in London (1981)',
#   'Vacation (1983)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Gremlins (1984)',
#   'A Nightmare on Elm Street (1984)'],
#  83: ['The Godfather: Part II (1974)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'The Fly (1986)',
#   'A Few Good Men (1992)',
#   'Heat (1995)',
#   'Meet Joe Black (1998)',
#   'Rush Hour (1998)',
#   'Fight Club (1999)',
#   'Sleepy Hollow (1999)'],
#  84: ['Bonnie and Clyde (1967)',
#   'Blade Runner (1982)',
#   'Hotaru no haka (1988)',
#   'Cinema Paradiso (1988)',
#   'Tonari no Totoro (1988)',
#   'Kurenai no buta (1992)',
#   'Mononoke-hime (1997)',
#   'PÃ¢fekuto burÃ» (1997)',
#   'The Lord of the Rings: The Two Towers (2002)',
#   'The Pianist (2002)'],
#  86: ["Singin' in the Rain (1952)",
#   '12 Angry Men (1957)',
#   'The Godfather (1972)',
#   'Star Wars (1977)',
#   'Hair (1979)',
#   'Star Wars: Episode V - The Empire Strikes Back (1980)',
#   'Star Wars: Episode VI - Return of the Jedi (1983)',
#   'Goodfellas (1990)',
#   'Batman: Mask of the Phantasm (1993)',
#   'LÃ©on (1994)'],
#  88: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)'],
#  91: ['The Deer Hunter (1978)',
#   'Fahrenheit 451 (2018)',
#   'A Walk Among the Tombstones (2014)',
#   'Jurassic World (2015)',
#   'Shazam! (2019)',
#   'Ex Machina (2014)',
#   'World War Z (2013)',
#   'Lone Survivor (2013)',
#   'Cold in July (2014)',
#   'Broken City (2013)'],
#  92: ['Come Live with Me (1941)',
#   "It's a Wonderful Life (1946)",
#   'Miracle on 34th Street (1947)',
#   'Cinderella (1950)',
#   'Calamity Jane (1953)',
#   'On the Waterfront (1954)',
#   'Rear Window (1954)',
#   'The Man from Laramie (1955)',
#   "Ocean's Eleven (1960)",
#   'Mary Poppins (1964)'],
#  93: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Taxi Driver (1976)',
#   'Scent of a Woman (1992)',
#   'Fever Pitch (1997)',
#   'Brokedown Palace (1999)',
#   'Any Given Sunday (1999)',
#   'Office Space (1999)',
#   'Requiem for a Dream (2000)',
#   'Almost Famous (2000)',
#   'The Secret Life of Walter Mitty (2013)'],
#  94: ['Superbad (2007)',
#   'The Edge of Seventeen (2016)',
#   'The Broken Circle Breakdown (2012)',
#   'The Accountant (2016)',
#   'The Magnificent Seven (2016)',
#   'Arrival (2016)',
#   'Jojo Rabbit (2019)',
#   'Lion (2016)',
#   'Baby Driver (2017)',
#   'Guardians of the Galaxy Vol. 2 (2017)'],
#  95: ['Barry Lyndon (1975)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'No Country for Old Men (2007)',
#   'Dallas Buyers Club (2013)',
#   'Mammoth (2009)',
#   'The Ides of March (2011)',
#   'The Hobbit: The Desolation of Smaug (2013)',
#   'Broken (2012)',
#   'Warm Bodies (2013)'],
#  97: ['Star Wars: Episode V - The Empire Strikes Back (1980)',
#   'Scarface (1983)',
#   'The Breakfast Club (1985)',
#   'Ace Ventura: Pet Detective (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'Office Space (1999)',
#   '8 Mile (2002)',
#   'The Machinist (2004)',
#   'The Terminal (2004)'],
#  98: ['American History X (1998)',
#   'Mud (2012)',
#   'The Kings of Summer (2013)',
#   'Before Midnight (2013)',
#   'Drinking Buddies (2013)',
#   'In a World... (2013)'],
#  100: ['Barry Lyndon (1975)',
#   'Dallas Buyers Club (2013)',
#   'Mammoth (2009)',
#   'The Ides of March (2011)',
#   'The Hobbit: The Desolation of Smaug (2013)',
#   'Jagten (2012)',
#   'Tesis sobre un homicidio (2013)',
#   'Le passÃ© (2013)',
#   'Magical Girl (2014)',
#   'Dheepan (2015)']}
